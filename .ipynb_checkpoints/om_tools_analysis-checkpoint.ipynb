# %%
# %matplotlib inline
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import re
import csv
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')

#variables
lxa_n = 10 #number of Alexa pages to scrape (25 sites per page)

def extract(html):
    soup = BeautifulSoup(html, "lxml")
    return [script.get('src') for script in soup.find_all('script')]

def extract_link(html):
    soup = BeautifulSoup(html, "lxml")
    for link in soup.find_all('p'):
        print link.text
        
def get_top_sites():
    top_links = []
    for i in range(lxa_n):
        lxa_url = "http://www.alexa.com/topsites/countries;%s/NL" % str(i)
        lxa = make_request(lxa_url).content
        soup = BeautifulSoup(lxa, "lxml")
        for link in soup.find_all('p', {'class' : 'desc-paragraph'}):
            if ".nl" in link.text:                          # only use dutch sites
                top_links.append(link.text)
    
    return top_links

def get_used_scripts():
    used_scripts = {}
    for site in top_sites:
        url = "http://www.%s" % site
        site_scripts = extract(make_request_async(url))
        used_scripts[site.strip()] = site_scripts
    
    return used_scripts
    
def make_request(url):
    headers = {'User-Agent' : 'Mozilla/5.0 Chrome/51.0.2704.106 Safari/537.36)'}
    req = requests.get(url, headers=headers) 
    return req

def make_request_async(url):
    browser = webdriver.Firefox()
    browser.get(url)
    source = browser.page_source
    browser.quit()
    return source

def dict_to_csv(data, name):
    with open(name, 'w') as f:
        w_csv = csv.writer(f)
        for k,v in data.items():
            w_csv.writerow([k.strip(), ",".join([str(x) for x in v])])
# Out:
#   File "<ipython-input-209-5cf3e32ce2c6>", line 56
#     def dict_to_csv(data, name)
#                                ^
# SyntaxError: invalid syntax

# %%
#common tools
tools = ["google-analytics", "piwik", "optimizely", "r42", "hotjar", "visualwebsiteoptimizer", 
      "usabilla", "adobedtm", "scorecardresearch", "nr-data", "crazyegg", "chartbeat", "krxd"]
frameworks = ["jquery", "angular", "bootstrap", "node", "underscore", "backbone"]

# find = re.search("(?=[^/]*$)(.+?)(\.js).*", line)

# %%
top_sites = get_top_sites()

# %%
top_sites_used_scripts = get_used_scripts()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-178-bf14032dd97f> in <module>()
# ----> 1 top_sites_used_scripts = get_used_scripts()
#
# <ipython-input-176-3e7c8e4b31c5> in get_used_scripts()
#      36     for site in top_sites:
#      37         url = "http://www.%s" % site
# ---> 38         site_scripts = extract(make_request_async(url))
#      39         used_scripts[site.strip()] = site_scripts
#      40
#
# <ipython-input-176-3e7c8e4b31c5> in make_request_async(url)
#      49     browser = webdriver.Firefox()
#      50     browser.get(url)
# ---> 51     source = browser.page_source
#      52     browser.quit()
#      53     return source
#
# //anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in page_source(self)
#     499             driver.page_source
#     500         """
# --> 501         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     502
#     503     def close(self):
#
# //anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     232
#     233         params = self._wrap_value(params)
# --> 234         response = self.command_executor.execute(driver_command, params)
#     235         if response:
#     236             self.error_handler.check_response(response)
#
# //anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/remote_connection.pyc in execute(self, command, params)
#     399         path = string.Template(command_info[1]).substitute(params)
#     400         url = '%s%s' % (self._url, path)
# --> 401         return self._request(command_info[0], url, body=data)
#     402
#     403     def _request(self, method, url, body=None):
#
# //anaconda/lib/python2.7/site-packages/selenium/webdriver/remote/remote_connection.pyc in _request(self, method, url, body)
#     431             try:
#     432                 self._conn.request(method, parsed_url.path, body, headers)
# --> 433                 resp = self._conn.getresponse()
#     434             except (httplib.HTTPException, socket.error):
#     435                 self._conn.close()
#
# //anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# //anaconda/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# //anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# //anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
top_sites_used_tools = {}

for site in top_sites_used_scripts:
    tools_used = {}
    for tool in tools:
        for item in top_sites_used_scripts[site]:
            if item is not None:
                if tool in item:
                    tools_used[tool] = 1
    top_sites_used_tools[site] = tools_used

# %%
dict_to_csv(top_sites_used_scripts, 'top_sites_used_scripts.csv')

# %%
df_tools = pd.DataFrame(data=top_sites_used_tools).transpose().fillna(0)
df_tools
# Out:
#                 adobedtm  chartbeat  crazyegg  google-analytics  nr-data  \
# Abnamro.nl             0          0         0                 0        0
# Ad.nl                  0          1         1                 1        0
# Ah.nl                  0          0         0                 0        0
# Beslist.nl             0          0         0                 0        0
# Buienradar.nl          0          0         0                 1        0
# Digid.nl\n             0          0         0                 0        0
# Dumpert.nl             0          0         0                 1        0
# Funda.nl               0          0         0                 1        1
# Google.nl              0          0         0                 0        0
# Ing.nl                 0          0         0                 0        0
# Marktplaats.nl         0          0         0                 1        0
# Nos.nl                 0          0         0                 0        0
# Npo.nl                 0          0         0                 0        0
# Nu.nl                  0          0         0                 1        1
# Rabobank.nl            0          0         0                 0        0
# Telegraaf.nl           0          0         0                 1        0
# Viraltrend.nl          0          0         0                 1        0
# Weeronline.nl          0          0         0                 1        0
# Wehkamp.nl             0          0         0                 1        1
# Ziggo.nl               1          0         0                 0        0
#
#                 optimizely  r42  scorecardresearch  usabilla
# Abnamro.nl               0    0                  0         1
# Ad.nl                    0    0                  1         0
# Ah.nl                    0    0                  0         0
# Beslist.nl               1    0                  0         0
# Buienradar.nl            0    0                  0         0
# Digid.nl\n               0    0                  0         0
# Dumpert.nl               0    0                  0         0
# Funda.nl                 1    0                  0         0
# Google.nl                0    0                  0         0
# Ing.nl                   0    0                  0         0
# Marktplaats.nl           1    0                  0         0
# Nos.nl                   0    0                  1         0
# Npo.nl                   0    0                  0         0
# Nu.nl                    1    0                  1         0
# Rabobank.nl              0    0                  0         0
# Telegraaf.nl             0    0                  0         0
# Viraltrend.nl            0    0                  0         0
# Weeronline.nl            0    0                  0         0
# Wehkamp.nl               1    0                  0         0
# Ziggo.nl                 0    1                  0         0

# %%
df_tools.transpose().plot.barh(stacked=True, figsize=(12,9))
